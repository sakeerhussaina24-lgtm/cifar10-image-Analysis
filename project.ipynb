# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
import matplotlib.pyplot as plt
import numpy as np
# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Print dataset shapes
print("Training images shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
print("Test images shape:", x_test.shape)
print("Test labels shape:", y_test.shape)
# Display sample images
plt.figure(figsize=(10, 10))
for i in range(25):
  plt.subplot(5, 5, i+1)
  plt.imshow(x_train[i])
  plt.title(y_train[i])
  plt.axis('off')
plt.show()
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Training images shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Test images shape: (10000, 32, 32, 3)
# Test labels shape: (10000, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
# Define CNN model architecture
model = Sequential([
  Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)),
  MaxPooling2D((2, 2)),
  Conv2D(64, (3, 3), activation='relu'),
  MaxPooling2D((2, 2)),
  Conv2D(128, (3, 3), activation='relu'),
  MaxPooling2D((2, 2)),
  Flatten(),
  Dense(128, activation='relu'),
  Dropout(0.2),
  Dense(10, activation='softmax')
])
# Compile model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Print model summary
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 62, 62, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
# Train the model
history = model.fit(
  x_train_resized,
  y_train,
  epochs=10,
  batch_size=32,
  validation_data=(x_test_resized, y_test)
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-985871378.py in <cell line: 0>()
#       1 # Train the model
#       2 history = model.fit(
# ----> 3   x_train_resized,
#       4   y_train,
#       5   epochs=10,
#
# NameError: name 'x_train_resized' is not defined

# %%
history = model.fit(
  x_train_resized,
  y_train,
  epochs=10,
  batch_size=32,
  validation_data=(x_test_resized, y_test)
)
# Out:
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 350s 223ms/step - accuracy: 0.3501 - loss: 1.7551 - val_accuracy: 0.5832 - val_loss: 1.1839
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 383s 223ms/step - accuracy: 0.5836 - loss: 1.1778 - val_accuracy: 0.6478 - val_loss: 1.0104
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 376s 219ms/step - accuracy: 0.6601 - loss: 0.9669 - val_accuracy: 0.6849 - val_loss: 0.9028
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 386s 222ms/step - accuracy: 0.7052 - loss: 0.8344 - val_accuracy: 0.7166 - val_loss: 0.8218
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 379s 221ms/step - accuracy: 0.7404 - loss: 0.7436 - val_accuracy: 0.7246 - val_loss: 0.7894
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 380s 219ms/step - accuracy: 0.7657 - loss: 0.6643 - val_accuracy: 0.7296 - val_loss: 0.7989
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 341s 218ms/step - accuracy: 0.7952 - loss: 0.5754 - val_accuracy: 0.7253 - val_loss: 0.8138
# Epoch 8/10
# ...

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np
import cv2
# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Normalize pixel values to range [0, 1]
x_train_normalized = x_train.astype('float32') / 255.0
x_test_normalized = x_test.astype('float32') / 255.0
# Resize images to 64x64
x_train_resized = np.array([cv2.resize(img, (64, 64)) for img in x_train_normalized])
x_test_resized = np.array([cv2.resize(img, (64, 64)) for img in x_test_normalized])
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Define CNN model architecture
model = Sequential([
  Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)),
  MaxPooling2D((2, 2)),
  Conv2D(64, (3, 3), activation='relu'),
  MaxPooling2D((2, 2)),
  Conv2D(128, (3, 3), activation='relu'),
  MaxPooling2D((2, 2)),
  Flatten(),
  Dense(128, activation='relu'),
  Dropout(0.2),
  Dense(10, activation='softmax')
])
# Compile model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Create ImageDataGenerator instance
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)
# Fit data augmentation to training data
datagen.fit(x_train_resized)
# Retrain model with augmented data
history = model.fit(
    datagen.flow(x_train_resized, y_train, batch_size=32),
    epochs=10,
    validation_data=(x_test_resized, y_test)
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 441s 281ms/step - accuracy: 0.2798 - loss: 1.9243 - val_accuracy: 0.4987 - val_loss: 1.3597
# Epoch 2/10
# ...

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
# Make predictions on test data
y_pred = model.predict(x_test_resized)
y_pred_class = y_pred.argmax(axis=1)
# Evaluate model performance
accuracy = accuracy_score(y_test, y_pred_class)
precision = precision_score(y_test, y_pred_class, average='macro')
recall = recall_score(y_test, y_pred_class, average='macro')
f1 = f1_score(y_test, y_pred_class, average='macro')
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Generate confusion matrix
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 62ms/step
# Accuracy: 0.6885
# Precision: 0.7022
# Recall: 0.6885
# F1-score: 0.6866

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
# Make predictions on test data
y_pred = model.predict(x_test_resized)
y_pred_class
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 19s 60ms/step
# array([3, 8, 8, ..., 5, 1, 7])

# %%
# Make predictions on test data
y_pred = model.predict(x_test_resized)
y_pred_class = y_pred.argmax(axis=1)
# Evaluate model performance
accuracy = accuracy_score(y_test, y_pred_class)
precision = precision_score(y_test, y_pred_class, average='macro')
recall = recall_score(y_test, y_pred_class, average='macro')
f1 = f1_score(y_test, y_pred_class, average='macro')
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 63ms/step
# Accuracy: 0.6885
# Precision: 0.7022
# Recall: 0.6885
# F1-score: 0.6866

# %%
import matplotlib.pyplot as plt
# Plot accuracy and loss curves
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Create ImageDataGenerator instance
datagen = ImageDataGenerator(
    rotation_range=30,  # Rotate images up to 30 degrees
    width_shift_range=0.2,  # Shift images horizontally up to 20%
    height_shift_range=0.2,  # Shift images vertically up to 20%
    horizontal_flip=True  # Flip images horizontally
)

# %%
import matplotlib.pyplot as plt
# Generate augmented images
augmented_images = datagen.flow(x_train_resized, y_train, batch_size=9)
# Plot augmented images
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(augmented_images.next()[0][i].astype('uint8'))
    plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-747491472.py in <cell line: 0>()
#       5 for i in range(9):
#       6     plt.subplot(3, 3, i+1)
# ----> 7     plt.imshow(augmented_images.next()[0][i].astype('uint8'))
#       8     plt.axis('off')
#       9 plt.show()
#
# AttributeError: 'NumpyArrayIterator' object has no attribute 'next'

# %%
import matplotlib.pyplot as plt
# Generate augmented images
augmented_images = datagen._get_batches_of_transformed_samples(x_train_resized, batch_size=9)
# Plot augmented images
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(augmented_images[0][i].astype('uint8'))
    plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1701114382.py in <cell line: 0>()
#       1 import matplotlib.pyplot as plt
#       2 # Generate augmented images
# ----> 3 augmented_images = datagen._get_batches_of_transformed_samples(x_train_resized, batch_size=9)
#       4 # Plot augmented images
#       5 for i in range(9):
#
# AttributeError: 'ImageDataGenerator' object has no attribute '_get_batches_of_transformed_samples'

# %%
import matplotlib.pyplot as plt
# Generate augmented images
augmented_images = datagen.flow(x_train_resized, y_train, batch_size=9)
# Get the first batch of augmented images
images = next(augmented_images)[0]
# Plot augmented images
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(images[i].astype('uint8'))
    plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt
# Generate augmented images
augmented_images = datagen.flow(x_train_resized, y_train, batch_size=9)
# Get the first batch of augmented images
images = next(augmented_images)[0]
# Rescale pixel values to [0, 255]
images = (images * 255).astype('uint8')
# Plot augmented images
for i in range(9):
    plt.subplot(3, 3, i+1)
    plt.imshow(images[i])
    plt.axis('off')
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
# Define CNN model architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])
# Compile model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Train model
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Load pre-trained MobileNetV2 model
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape
# Out:
#   File "/tmp/ipython-input-1023463396.py", line 7
#     base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape
#                                                                                ^
# SyntaxError: incomplete input

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score
# Load pre-trained MobileNetV2 model
base_model = MobileNetV2(weights='imagenet',
                        include_top=False,
                        input_shape=(64, 64, 3))
# Freeze base model layers
base_model.trainable = False
# Define custom model with MobileNetV2 as base
x = base_model.output
x = Flatten()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(10, activation='softmax')(x)
# Define custom model
model = Model(inputs=base_model.input, outputs=x)
# Compile custom model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Define early stopping callback
early_stopping = EarlyStopping(patience=5, min_delta=0.001)
# Define ImageDataGenerator for training data
train_datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)
train_datagen.fit(x_train_resized)
# Train custom model
history = model.fit(train_datagen.flow(x_train_resized, y_train, batch_size=32),
                    epochs=10,
                    validation_data=(x_test_resized, y_test),
                    callbacks=[early_stopping])
# Evaluate custom model
loss, accuracy = model.evaluate(x_test_resized, y_test)
print(f'Test loss: {loss:.4f}')
print(f'Test accuracy: {accuracy:.4f}')
# Make predictions on test data
y_pred = model.predict(x_test_resized)
y_pred_class = y_pred.argmax(axis=1)
# Calculate
# Out:
# /tmp/ipython-input-2984884971.py:9: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(weights='imagenet',
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 284s 177ms/step - accuracy: 0.4518 - loss: 1.5768 - val_accuracy: 0.6064 - val_loss: 1.1233
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 261s 167ms/step - accuracy: 0.5299 - loss: 1.3375 - val_accuracy: 0.6306 - val_loss: 1.0617
# Epoch 3/10
# ...
